# %% [markdown]
# # Astrophage Solar Simulation
#
# This notebook-style file explains the same workflow as `main.py`.
# Run `main.py` for the full automatic version.

# %% [markdown]
# ## Model
#
# $$E_{surface}(t)=E_{observed}(t)e^{-\lambda t}$$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

monthly = pd.read_csv('data/processed/monthly_solar_data.csv')
monthly['date'] = pd.to_datetime(monthly['date'])

rates = [0.000, 0.003, 0.006, 0.010]
for rate in rates:
    attenuation = np.exp(-rate * monthly['month_index'])
    simulated = monthly['solar_radiation_mean'] * attenuation
    plt.plot(monthly['date'], simulated, label=f'lambda={rate}')

plt.plot(monthly['date'], monthly['solar_radiation_mean'], label='observed', linewidth=2)
plt.xlabel('Date')
plt.ylabel('Monthly Mean Solar Radiation')
plt.title('Astrophage Solar Energy Attenuation Simulation')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
